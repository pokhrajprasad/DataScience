# %%
import pandas as pd

# %%
data=[1,2,3,4,5]
series=pd.Series(data)
print(series)
print(type(series))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
data={'a':1,'b':2,'c':3}
series_dict=pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data=[10,20,30]
index=['a','b','c']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
data={
    'Name':['Pokhraj','Krish','John'],
    'Age':[25,30,45],
    'City':['Bangalore','New York','Florida']
}
df=pd.DataFrame(data)
print(df)
# Out:
#       Name  Age       City
# 0  Pokhraj   25  Bangalore
# 1    Krish   30   New York
# 2     John   45    Florida

# %%
import numpy as np

np.array(df)
# Out:
# array([['Pokhraj', 25, 'Bangalore'],
#        ['Krish', 30, 'New York'],
#        ['John', 45, 'Florida']], dtype=object)

# %%
data=[
    {'Name':'Pokhraj','Age':26,'City':'Bangalore'},
    {'Name':'Krish','Age':30,'City':'New York'},
    {'Name':'John','Age':45,'City':'Florida'}  
]

df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#       Name  Age       City
# 0  Pokhraj   26  Bangalore
# 1    Krish   30   New York
# 2     John   45    Florida
# <class 'pandas.core.frame.DataFrame'>

# %%
df=pd.read_csv(r'C:\Users\pokhr\Desktop\Work\Data Science\Data\supermarket_sales - Sheet1.csv')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data=[
    {'Name':'Pokhraj','Age':26,'City':'Bangalore'},
    {'Name':'Krish','Age':30,'City':'New York'},
    {'Name':'John','Age':45,'City':'Florida'}  
]

df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#       Name  Age       City
# 0  Pokhraj   26  Bangalore
# 1    Krish   30   New York
# 2     John   45    Florida
# <class 'pandas.core.frame.DataFrame'>

# %%
df['Name']
# Out:
# 0    Pokhraj
# 1      Krish
# 2       John
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df.loc[1]['Name']
# Out:
# 'Krish'

# %%
df.iloc[1][0]
# Out:
# C:\Users\pokhr\AppData\Local\Temp\ipykernel_18092\1019881219.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[1][0]
# 'Krish'

# %%
df.loc[0:2]
# Out:
#       Name  Age       City
# 0  Pokhraj   26  Bangalore
# 1    Krish   30   New York
# 2     John   45    Florida

# %%
df.iloc[0:2]
# Out:
#       Name  Age       City
# 0  Pokhraj   26  Bangalore
# 1    Krish   30   New York

# %%
df
# Out:
#       Name  Age       City
# 0  Pokhraj   26  Bangalore
# 1    Krish   30   New York
# 2     John   45    Florida

# %%
df.at[1,'Age']
# Out:
# 30

# %%
df.at[2,'Name']
# Out:
# 'John'

# %%
df.iat[2,2]
# Out:
# 'Florida'

# %%
df
# Out:
#       Name  Age       City
# 0  Pokhraj   26  Bangalore
# 1    Krish   30   New York
# 2     John   45    Florida

# %%
df['Salary']=[50000,60000,30000]

# %%
df
# Out:
#       Name  Age       City  Salary
# 0  Pokhraj   26  Bangalore   50000
# 1    Krish   30   New York   60000
# 2     John   45    Florida   30000

# %%
df.drop('Salary',axis=1)
# Out:
#       Name  Age       City
# 0  Pokhraj   26  Bangalore
# 1    Krish   30   New York
# 2     John   45    Florida

# %%
df
# Out:
#       Name  Age       City  Salary
# 0  Pokhraj   26  Bangalore   50000
# 1    Krish   30   New York   60000
# 2     John   45    Florida   30000

# %%
df.drop('Salary',axis=1,inplace=True)

# %%
df
# Out:
#       Name  Age       City
# 0  Pokhraj   26  Bangalore
# 1    Krish   30   New York
# 2     John   45    Florida

# %%
df['Age']+=1

# %%
df
# Out:
#       Name  Age       City
# 0  Pokhraj   27  Bangalore
# 1    Krish   31   New York
# 2     John   46    Florida

# %%
df.drop(0)
# Out:
#     Name  Age      City
# 1  Krish   31  New York
# 2   John   46   Florida

# %%
df.drop(0, inplace=True)

# %%
df
# Out:
#     Name  Age      City
# 1  Krish   31  New York
# 2   John   46   Florida

# %%
df=pd.read_csv(r'C:\Users\pokhr\Desktop\Work\Data Science\Data\supermarket_sales - Sheet1.csv')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
print(df.dtypes)
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df=pd.read_csv(r'..\..\Data\supermarket_sales - Sheet1.csv')

# %%
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Invoice ID                 False
# Branch                     False
# City                       False
# Customer type              False
# Gender                     False
# Product line               False
# Unit price                 False
# Quantity                   False
# Tax 5%                     False
# Total                      False
# Date                       False
# Time                       False
# Payment                    False
# cogs                       False
# gross margin percentage    False
# gross income               False
# Rating                     False
# dtype: bool

# %%
df_filled=df.fillna(0)

# %%
df['Total']=df['Total'].fillna(df['Total'].mean())

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df=df.rename(columns={'Total':'Total_Amount'})

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%  Total_Amount  \
# 0       Health and beauty       74.69         7  26.1415      548.9715
# 1  Electronic accessories       15.28         5   3.8200       80.2200
# 2      Home and lifestyle       46.33         7  16.2155      340.5255
# 3       Health and beauty       58.22         8  23.2880      489.0480
# 4       Sports and travel       86.31         7  30.2085      634.3785
#
#         Date   Time      Payment    cogs  gross margin percentage  \
# 0   1/5/2019  13:08      Ewallet  522.83                 4.761905
# 1   3/8/2019  10:29         Cash   76.40                 4.761905
# ...

# %%
df['Total_Amount']=df['Total_Amount'].astype(int)

# %%
df['Total_Amount']
# Out:
# 0       548
# 1        80
# 2       340
# 3       489
# 4       634
#        ...
# 995      42
# 996    1022
# 997      33
# 998      69
# 999     649
# Name: Total_Amount, Length: 1000, dtype: int32

# %%
df['Total_Amount_new']=df['Total_Amount'].apply(lambda x:x*2)

# %%
df['Total_Amount_new']
# Out:
# 0      1096
# 1       160
# 2       680
# 3       978
# 4      1268
#        ...
# 995      84
# 996    2044
# 997      66
# 998     138
# 999    1298
# Name: Total_Amount_new, Length: 1000, dtype: int64

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%  Total_Amount  \
# 0         Health and beauty       74.69         7  26.1415           548
# 1    Electronic accessories       15.28         5   3.8200            80
# ...

# %%
grouped_mean=df.groupby('Gender')['Total_Amount'].mean()

# %%
grouped_mean
# Out:
# Gender
# Female    334.604790
# Male      310.284569
# Name: Total_Amount, dtype: float64

# %%
grouped_sum=df.groupby(['Gender','City'])['Total_Amount'].sum()

# %%
grouped_mean
# Out:
# Gender  City
# Female  Mandalay     326.234568
#         Naypyitaw    346.061798
#         Yangon       330.360248
# Male    Mandalay     312.835294
#         Naypyitaw    325.393333
#         Yangon       295.201117
# Name: Total_Amount, dtype: float64

# %%
grouped_agg=df.groupby(['City','Gender'])['Total_Amount'].agg(['mean','sum','count'])

# %%
grouped_agg
# Out:
#                         mean    sum  count
# City      Gender
# Mandalay  Female  326.234568  52850    162
#           Male    312.835294  53182    170
# Naypyitaw Female  346.061798  61599    178
#           Male    325.393333  48809    150
# Yangon    Female  330.360248  53188    161
#           Male    295.201117  52841    179

# %%
df1=pd.DataFrame({'Key':['A','B','C','A'], 'Value':[1,2,3,7]})
df2=pd.DataFrame({'Key':['A','B','D'], 'Value':[4,5,6]})

# %%
df1
# Out:
#   Key  Value
# 0   A      1
# 1   B      2
# 2   C      3
# 3   A      7

# %%
df2
# Out:
#   Key  Value
# 0   A      4
# 1   B      5
# 2   D      6

# %%
pd.merge(df1,df2,on='Key',how='inner')
# Out:
#   Key  Value_x  Value_y
# 0   A        1        4
# 1   B        2        5
# 2   A        7        4

# %%
pd.merge(df1,df2,on='Key',how='outer')
# Out:
#   Key  Value_x  Value_y
# 0   A      1.0      4.0
# 1   A      7.0      4.0
# 2   B      2.0      5.0
# 3   C      3.0      NaN
# 4   D      NaN      6.0

# %%
pd.merge(df1,df2,on='Key',how='left')
# Out:
#   Key  Value_x  Value_y
# 0   A        1      4.0
# 1   B        2      5.0
# 2   C        3      NaN
# 3   A        7      4.0

# %%
pd.merge(df1,df2,on='Key',how='right')
# Out:
#   Key  Value_x  Value_y
# 0   A      1.0        4
# 1   A      7.0        4
# 2   B      2.0        5
# 3   D      NaN        6

# %%
import json
data = {
    "name": "John Doe",
    "email": "john.doe@example.com",
    "job profile": 'NA'
}

# Convert the dictionary to a string that looks like a dictionary
json_string = json.dumps(data)

# %%
json_string
# Out:
# '{"name": "John Doe", "email": "john.doe@example.com", "job profile": "NA"}'

# %%
from io import StringIO

# %%
df=pd.read_json(StringIO(json_string))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 df=pd.read_json(StringIO(json_string))
#
# File c:\Users\pokhr\anaconda3\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File c:\Users\pokhr\anaconda3\Lib\site-packages\pandas\io\json\_json.py:1025, in JsonReader.read(self)
#    1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
# -> 1025     obj = self._get_object_parser(self.data)
#    1026 if self.dtype_backend is not lib.no_default:
#    1027     return obj.convert_dtypes(
# ...

# %%
import pandas as pd
from io import StringIO
data='{"employee":"james","email":"james@gmail.com"}'
df=pd.read_json(StringIO(data),lines=True)

# %%
df
# Out:
#   employee            email
# 0    james  james@gmail.com

# %%
df.to_json()
# Out:
# '{"employee":{"0":"james"},"email":{"0":"james@gmail.com"}}'

# %%
df.to_json(orient='index')
# Out:
# '{"0":{"employee":"james","email":"james@gmail.com"}}'

# %%
df.to_json(orient='records')
# Out:
# '[{"employee":"james","email":"james@gmail.com"}]'

# %%
url="https://en.wikipedia.org/wiki/Nvidia"
df=pd.read_html(url,match='Business unit')

# %%
df[0]
# Out:
#           Business unit  Sales (billion $)  Share
# 0  Compute & networking               47.4  77.8%
# 1              Graphics               13.5  22.2%
